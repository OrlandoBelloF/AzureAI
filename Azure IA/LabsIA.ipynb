# %% [markdown]
# # Practicas de Computer Vision

# %%
# Se establecen las credenciales
key = '60fee70b03204f2bad3dc77602d49fcf'
endpoint = 'https://cv-drla1.cognitiveservices.azure.com/'

# %%
# Conectamos con Azure
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client = ComputerVisionClient (endpoint, CognitiveServicesCredentials(key))

# %%
import os
import vision

# %matplotlib inline

# Obtenemos la imagen
image_path = './data/vision/D.jpg'

image_stream = open (image_path, "rb")
description = client.describe_image_in_stream(image_stream)
print(description)

vision.show_image_caption(image_path, description)
# Out:
# {'additional_properties': {}, 'tags': ['tree', 'reptile', 'dinosaur', 'animal'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x000002583BC5D570>], 'request_id': '94563411-c3a7-471a-8f95-5d6e5939a02b', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x000002583BC44520>, 'model_version': '2021-05-01'}

# %%
image_path = './data/vision/D2.jpg'

image_stream = open (image_path, "rb")
detected_faces = client.face.detect_with_stream(image = image_stream)
description = client.describe_image_in_stream(image_stream)
print(description)

faces.show_faces(image_path, detected_faces, show id = true)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Enfoque\Desktop\Portafolio\Azure\Azure IA\LabsIA.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Enfoque/Desktop/Portafolio/Azure/Azure%20IA/LabsIA.ipynb#ch0000004?line=0'>1</a> image_path = './data/vision/D2.jpg'
#       <a href='vscode-notebook-cell:/c%3A/Users/Enfoque/Desktop/Portafolio/Azure/Azure%20IA/LabsIA.ipynb#ch0000004?line=2'>3</a> image_stream = open (image_path, "rb")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Enfoque/Desktop/Portafolio/Azure/Azure%20IA/LabsIA.ipynb#ch0000004?line=3'>4</a> detected_faces = client.face.detect_with_stream(image = image_stream)
#       <a href='vscode-notebook-cell:/c%3A/Users/Enfoque/Desktop/Portafolio/Azure/Azure%20IA/LabsIA.ipynb#ch0000004?line=4'>5</a> description = client.describe_image_in_stream(image_stream)
# ...
